# %% [markdown]
# # Projeto de Criação de um Pipeline de ETL
#
# Um Pipeline de ETL é formado pelas seguintes fases:
# - Extract - nessa fase os dados são coletados de diferentes fontes.
# - Transform - aqui são transformados para atender as necessidades da análise ou armazenamento.
# - Load - inserir os dados transformados para um destino final.

# %% [markdown]
# ## Introdução ao Projeto
#
# - O projeto consiste em pegar duas bases de dados, uma relacionada ao cadastro de clientes e outra do cadastro de transações bancárias.
# - Fazer as transformações necessárias como limpeza dos dados e agrupamento.
# - Depois disso será criado mais duas base de dados, uma contendo os clientes que não terão cobranças na conta no próximo ano e também ofertas especiais de investimento e uma outra base com clientes que não vão ter benefícios.

# %% [markdown]
# ### Importando as bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# ### Importando as base de dados

# %%
clientes = pd.read_excel('CasdastroCliente.xlsx')
transacao = pd.read_excel('CadastroTransacoes.xlsx')

display(clientes)
display(transacao)
# Out:
#    ID Cliente Primeiro Nome     Sobrenome Data Nascimento  Idade Gênero  \
# 0        H001     Sthefeson     Bernhardt      1966-04-08   57.0      M
# 1        H002       Antonio       Vannier      1985-05-14   38.0      M
# 2        H003        Bianca         Kranz      1965-08-12   58.0      F
# 3        H004        Silvio       Almeida      1998-02-15   25.0      M
# 4        H005         Luiza        Moraes      1968-08-08   55.0      F
# 5        H006           Ana     Villanova      1965-08-05   58.0      F
# 6        H007       Natalia        Amaral      1964-05-09   59.0      F
# 7        H008      Leonardo          Lima      1984-07-07   39.0      M
# 8        H009          Chan      Marchesi      1964-04-01   59.0      F
# 9        H010      Fernanda        Freire      1964-01-06   59.0      F
# 10       H011        Raissa         Souza      1999-11-04   24.0      F
# 11       H012        Arthur         Assis      1998-01-18    NaN      M
# 12       H013       Eduardo        Barros      1994-08-06   29.0      M
# 13       H014          João        Correa      1978-05-09   45.0      M
# 14       H015          Caio       Almeida      1979-02-27   44.0      M
# 15       H016         Tiago      Ferreira      1975-04-28   48.0      M
# 16       H017         Julia       Pimenta      1995-06-26   28.0      F
# 17       H018      Bernardo     Wajnsztok      1966-05-08   57.0      M
# 18       H019        Victor     Conceição      1966-05-14   57.0      M
# 19       H020         Thays         Mello      1965-08-15   58.0      F
# 20       H021          Ruan         Rocha      1982-02-15   41.0      M
# 21       H022       Mariana         Alves      1968-08-08   55.0      F
# 22       H023     Alexandre  Vasconcellos      1965-08-05   58.0      M
# 23       H024       Natalia        Araujo      1989-05-09   34.0      F
# 24       H025       Manuela          Melo      1964-07-07   59.0      F
# 25       H026         Bruna         Netto      2000-04-01   23.0      F
# 26       H027          Caio          Maia      1964-01-06   59.0      M
# 27       H028      Bernardo     Viríssimo      1969-11-04   54.0      M
# 28       H029       Rodrigo      Carvalho      1998-01-18   25.0      M
# 29       H030         Pedro     Magalhães      2003-08-06    NaN      M
# 30       H031      Giuseppe      Mendonça      1978-05-09   45.0      M
# 31       H032       Isabela          Maia      1966-04-08   57.0      F
# 32       H033         Raíza        Mendes      1985-05-14   38.0      F
# 33       H034        Wilson       Santana      1965-08-12   58.0      M
# 34       H035       Larissa         Zakhm      1994-02-15   29.0      F
# 35       H036         Luíza        Albino      1968-08-08   55.0      F
# 36       H037      Fernanda        Taylor      1965-08-05   58.0      F
# 37       H038        Bianca     Assumpção      1964-05-09   59.0      F
# 38       H039         Diogo        Veloso      1967-07-07   56.0      M
# 39       H040        Cícero     Bernhardt      1964-04-01   59.0      M
# 40       H041       Raphael       Freitas      1973-01-06   50.0      M
# 41       H042         Fabio      Capitulo      1969-11-04   54.0      M
# 42       H043       Manuela    Cavalcanti      1998-01-18   25.0      F
# 43       H044       Juliana          Lima      1994-08-06   29.0      F
# 44       H045       Jéssica        Barros      1978-05-09    NaN      F
# 45       H046      Adrielle      Assunção      1997-02-27   26.0      F
# 46       H047        Thayna       Accardo      1989-04-28   34.0      F
# 47       H048         Pedro         Jesus      1959-06-26   64.0      M
# 48       H049       Juliana        Tostes      1966-04-08   57.0      F
# 49       H050         Tayla          Melo      2005-05-14   18.0      F
#
#                                 Endereço        Telefone  Número da Conta
# 0        Rua Winthrop Hedau, 2769 centro  (71) 921679744          3499072
# 1           Rua Mead Spargo, 4055 centro  (62) 954043135          8048679
# 2         Rua Gabbie Pottie, 2289 centro  (27) 909825530          3573422
# 3           Rua Tasia Croot, 9875 centro  (96) 946617185          5763071
# 4       Rua Seth Brailsford, 8134 centro  (86) 929775335          5954411
# 5          Rua Peggy Parmer, 8302 centro  (82) 992446706          1699507
# 6         Rua Mildrid Drane, 2032 centro  (68) 948576145          2507159
# 7          Rua Muriel Beste, 2636 centro  (63) 933027844          2745571
# 8            Rua Kiele Deme, 7271 centro  (98) 942216405          6600189
# 9          Rua Uriah Firmin, 8677 centro  (98) 939451468          1411453
# 10      Rua Mozes Wickliffe, 5015 centro  (83) 940192383          8720104
# 11     Rua Renard Gravenell, 8517 centro  (88) 901527421          5193866
# 12          Rua Sal Loosely, 1632 centro  (86) 993872650          4779074
# 13        Rua Gardy Skippon, 3723 centro  (41) 923997232          2036165
# 14      Rua Candide Manolov, 1168 centro  (62) 970051595          9211792
# 15   Rua Prissie Witheridge, 6697 centro  (95) 983847686          1716868
# 16     Rua Reine Mclanachan, 4338 centro  (62) 968443268          6704562
# 17           Rua Gae Thowes, 6194 centro  (69) 993925290          7181109
# 18   Rua Leonerd Segebrecht, 1331 centro  (69) 915168994          7004593
# 19        Rua Paxon Shillum, 5744 centro  (88) 940567772          4911058
# 20     Rua Callean Bernetti, 1243 centro  (86) 992324924          3489011
# 21       Rua Marketa Dibley, 3326 centro  (68) 943665850          5487087
# 22     Rua Lissie Paolicchi, 9309 centro  (98) 978457502          6431645
# 23          Rua Saxe Boothe, 6864 centro  (86) 931735206          3770984
# 24      Rua Charmine Elgram, 1007 centro  (79) 921230380          7439183
# 25     Rua Victoria Caltera, 2703 centro  (84) 927896505          2987430
# 26        Rua Sammy Dansken, 1866 centro  (65) 995304740          5365171
# 27         Rua Karin Wimmer, 8986 centro  (98) 947493638          3847727
# 28        Rua Tedmund Jakov, 4093 centro  (84) 968414800          1426538
# 29         Rua Annis Merida, 9800 centro  (91) 944184729          5812144
# 30        Rua Ursola Bowick, 5930 centro  (62) 955949458          2816647
# 31      Rua Davidson Correa, 5747 centro  (71) 915122505          4681642
# 32         Rua Moria Simoni, 7790 centro  (41) 991221681          9996164
# 33  Rua Aubrette Campanelli, 4449 centro  (27) 920668719          1524997
# 34       Rua Jonell Fereday, 6237 centro  (48) 906603954          9539657
# 35       Rua Lyndell Tilbey, 2481 centro  (84) 946412449          8868672
# 36           Rua Mike Drury, 8013 centro  (61) 981720007          2265968
# 37   Rua Franklyn Woolcocks, 3969 centro  (92) 910641218          5186737
# 38     Rua Fred Summerfield, 9742 centro  (11) 926142846          6547371
# 39       Rua Dante Cotilard, 8016 centro  (81) 993765169          6520787
# 40      Rua Anselm Caulcutt, 4802 centro  (83) 989882612          7972394
# 41       Rua Zondra Gillise, 4881 centro  (83) 999460564          7607098
# 42      Rua Domingo Sprules, 7434 centro  (61) 959932281          1459889
# 43      Rua Garrett Gobeaux, 9966 centro  (61) 992242682          8877004
# 44         Rua Weber Vigors, 8024 centro  (92) 930205453          6256174
# 45     Rua Cathleen Wilbore, 4489 centro  (83) 901139740          6725534
# 46        Rua Davis Mcgarva, 2420 centro  (51) 914310078          1979681
# 47          Rua Dasha Kupka, 5775 centro  (31) 984570190          3394696
# 48         Rua Shandie Kemp, 2479 centro  (51) 932154836          2236263
# 49       Rua Farlie Beachem, 7902 centro  (84) 925534918          5664914
#      ID Transacao       Data Tipo de Transacao  Valor  Conta Origem Transacao
# 0               1 2023-02-21     Transferência    300                 6547371
# 1               2 2023-05-22     Transferência   1200                 7181109
# 2               3 2023-02-27          Depósito    600                 9996164
# 3               4 2023-02-20             Saque    200                 5812144
# 4               5 2023-10-25     Transferência   1700                 7439183
# ..            ...        ...               ...    ...                     ...
# 347           348 2023-04-03     Transferência    400                 6704562
# 348           349 2023-04-25          Depósito    500                 2265968
# 349           350 2023-03-20             Saque   1800                 4681642
# 350           341 2023-02-13     Transferência    800                 1459889
# 351           330 2023-06-22     Transferência   1100                 5664914
#
# [352 rows x 5 columns]

# %% [markdown]
# ### Entendo os dados e os transformando

# %% [markdown]
# - Tabela clientes

# %%
clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID Cliente       50 non-null     object
#  1   Primeiro Nome    50 non-null     object
#  2   Sobrenome        50 non-null     object
#  3   Data Nascimento  50 non-null     datetime64[ns]
#  4   Idade            47 non-null     float64
#  5   Gênero           50 non-null     object
#  6   Endereço         50 non-null     object
#  7   Telefone         50 non-null     object
#  8   Número da Conta  50 non-null     int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(6)
# memory usage: 3.6+ KB

# %%
clientes[clientes['Idade'].isnull()]
# Out:
#    ID Cliente Primeiro Nome  Sobrenome Data Nascimento  Idade Gênero  \
# 11       H012        Arthur      Assis      1998-01-18    NaN      M
# 29       H030         Pedro  Magalhães      2003-08-06    NaN      M
# 44       H045       Jéssica     Barros      1978-05-09    NaN      F
#
#                              Endereço        Telefone  Número da Conta
# 11  Rua Renard Gravenell, 8517 centro  (88) 901527421          5193866
# 29      Rua Annis Merida, 9800 centro  (91) 944184729          5812144
# 44      Rua Weber Vigors, 8024 centro  (92) 930205453          6256174

# %% [markdown]
# Como possui somente três valores ausentes na coluna 'Idade' e dar para preecher porque possui a coluna de 'Data Nascimento'. Vou preencher cada um manualmente.

# %%
# Preenchendo a idade dos clientes com valores ausentes
clientes.loc[clientes['ID Cliente']=='H012', 'Idade'] = 25
clientes.loc[clientes['ID Cliente']=='H030', 'Idade'] = 20
clientes.loc[clientes['ID Cliente']=='H045', 'Idade'] = 45

# %%
# Olhando se a tabela clientes ainda possui valores ausentes
clientes.isnull().sum()
# Out:
# ID Cliente         0
# Primeiro Nome      0
# Sobrenome          0
# Data Nascimento    0
# Idade              0
# Gênero             0
# Endereço           0
# Telefone           0
# Número da Conta    0
# dtype: int64

# %%
# Olhando se possui valores duplicados
clientes.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Vou juntar o primeiro nome com o sobrenome e depois apagar as colunas 'Primeiro Nome' e 'Sobrenome'.

# %%
# Criando a coluna Nome Completo
clientes['Nome Completo'] = clientes['Primeiro Nome'].str.cat(clientes['Sobrenome'], sep=' ')

# %%
# Apagando as colunas 
clientes = clientes.drop(['Primeiro Nome', 'Sobrenome'], axis=1)

# %%
clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID Cliente       50 non-null     object
#  1   Data Nascimento  50 non-null     datetime64[ns]
#  2   Idade            50 non-null     float64
#  3   Gênero           50 non-null     object
#  4   Endereço         50 non-null     object
#  5   Telefone         50 non-null     object
#  6   Número da Conta  50 non-null     int64
#  7   Nome Completo    50 non-null     object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 3.2+ KB

# %% [markdown]
# - Tabela transacao

# %%
transacao.head()
# Out:
#    ID Transacao       Data Tipo de Transacao  Valor  Conta Origem Transacao
# 0             1 2023-02-21     Transferência    300                 6547371
# 1             2 2023-05-22     Transferência   1200                 7181109
# 2             3 2023-02-27          Depósito    600                 9996164
# 3             4 2023-02-20             Saque    200                 5812144
# 4             5 2023-10-25     Transferência   1700                 7439183

# %%
transacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352 entries, 0 to 351
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID Transacao            352 non-null    int64
#  1   Data                    352 non-null    datetime64[ns]
#  2   Tipo de Transacao       352 non-null    object
#  3   Valor                   352 non-null    int64
#  4   Conta Origem Transacao  352 non-null    int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 13.9+ KB

# %%
# Verificando valores nulos
transacao.isnull().sum()
# Out:
# ID Transacao              0
# Data                      0
# Tipo de Transacao         0
# Valor                     0
# Conta Origem Transacao    0
# dtype: int64

# %%
# Verificando valores duplicados
transacao.duplicated().sum()
# Out:
# 2

# %%
# Removendo os valores duplicados
transacao = transacao.drop_duplicates()

# %% [markdown]
# Vou agrupar os dados pelo número da conta e ver quantas transações cada cliente fez ao longo do ano

# %%
transacao.groupby('Conta Origem Transacao').count()
# Out:
#                         ID Transacao  Data  Tipo de Transacao  Valor
# Conta Origem Transacao
# 1411453                           11    11                 11     11
# 1426538                            7     7                  7      7
# 1459889                            9     9                  9      9
# 1524997                            7     7                  7      7
# 1699507                            3     3                  3      3
# 1716868                            4     4                  4      4
# 1979681                            4     4                  4      4
# 2036165                            5     5                  5      5
# 2236263                           12    12                 12     12
# 2265968                           12    12                 12     12
# 2507159                            9     9                  9      9
# 2745571                            8     8                  8      8
# 2816647                            7     7                  7      7
# 2987430                            4     4                  4      4
# 3394696                            8     8                  8      8
# 3489011                            9     9                  9      9
# 3499072                            8     8                  8      8
# 3573422                            5     5                  5      5
# 3770984                            3     3                  3      3
# 3847727                            6     6                  6      6
# 4681642                            6     6                  6      6
# 4779074                            6     6                  6      6
# 4911058                            6     6                  6      6
# 5186737                            7     7                  7      7
# 5193866                            4     4                  4      4
# 5365171                            7     7                  7      7
# 5487087                            4     4                  4      4
# 5664914                            6     6                  6      6
# 5763071                            1     1                  1      1
# 5812144                            5     5                  5      5
# 5954411                            8     8                  8      8
# 6256174                            4     4                  4      4
# 6431645                            3     3                  3      3
# 6520787                           12    12                 12     12
# 6547371                            7     7                  7      7
# 6600189                           11    11                 11     11
# 6704562                            8     8                  8      8
# 6725534                           10    10                 10     10
# 7004593                            7     7                  7      7
# 7181109                            8     8                  8      8
# 7439183                            8     8                  8      8
# 7607098                            7     7                  7      7
# 7972394                           11    11                 11     11
# 8048679                            9     9                  9      9
# 8720104                            8     8                  8      8
# 8868672                            8     8                  8      8
# 8877004                            6     6                  6      6
# 9211792                            7     7                  7      7
# 9539657                            7     7                  7      7
# 9996164                            8     8                  8      8

# %% [markdown]
# Clientes que tiveram 10 ou mais transações ao longo do ano vão receber o benefício de não terem gastos com sua conta no próximo ano e também terão ofertas especiais de investimento, enquanto os outros não terão nenhum benefício.

# %%
# Criando uma tabela de transacao agrupada
transacao_agrupada = transacao.groupby('Conta Origem Transacao').count()

# %%
# Criando uma tabela com as contas que tiveram mais de nove transações no ano
tabela_mais_9_transacao = transacao_agrupada.loc[transacao_agrupada['ID Transacao']>=10, :].reset_index()

# %%
# Foi criado uma lista para pegar as contas com maiores transações
lista_conta_mais_9_transacao = []

for linha in tabela_mais_9_transacao['Conta Origem Transacao']:
    lista_conta_mais_9_transacao.append(linha)

print(lista_conta_mais_9_transacao)
# Out:
# [1411453, 2236263, 2265968, 6520787, 6600189, 6725534, 7972394]

# %%
# Criando uma tabela com contas com menos de 10 transações
tabela_menos_10_transacao = transacao_agrupada.loc[transacao_agrupada['ID Transacao']<10, :].reset_index()
tabela_menos_10_transacao
# Out:
#     Conta Origem Transacao  ID Transacao  Data  Tipo de Transacao  Valor
# 0                  1426538             7     7                  7      7
# 1                  1459889             9     9                  9      9
# 2                  1524997             7     7                  7      7
# 3                  1699507             3     3                  3      3
# 4                  1716868             4     4                  4      4
# 5                  1979681             4     4                  4      4
# 6                  2036165             5     5                  5      5
# 7                  2507159             9     9                  9      9
# 8                  2745571             8     8                  8      8
# 9                  2816647             7     7                  7      7
# 10                 2987430             4     4                  4      4
# 11                 3394696             8     8                  8      8
# 12                 3489011             9     9                  9      9
# 13                 3499072             8     8                  8      8
# 14                 3573422             5     5                  5      5
# 15                 3770984             3     3                  3      3
# 16                 3847727             6     6                  6      6
# 17                 4681642             6     6                  6      6
# 18                 4779074             6     6                  6      6
# 19                 4911058             6     6                  6      6
# 20                 5186737             7     7                  7      7
# 21                 5193866             4     4                  4      4
# 22                 5365171             7     7                  7      7
# 23                 5487087             4     4                  4      4
# 24                 5664914             6     6                  6      6
# 25                 5763071             1     1                  1      1
# 26                 5812144             5     5                  5      5
# 27                 5954411             8     8                  8      8
# 28                 6256174             4     4                  4      4
# 29                 6431645             3     3                  3      3
# 30                 6547371             7     7                  7      7
# 31                 6704562             8     8                  8      8
# 32                 7004593             7     7                  7      7
# 33                 7181109             8     8                  8      8
# 34                 7439183             8     8                  8      8
# 35                 7607098             7     7                  7      7
# 36                 8048679             9     9                  9      9
# 37                 8720104             8     8                  8      8
# 38                 8868672             8     8                  8      8
# 39                 8877004             6     6                  6      6
# 40                 9211792             7     7                  7      7
# 41                 9539657             7     7                  7      7
# 42                 9996164             8     8                  8      8

# %%
# Foi criado uma lista para pegar as contas com menores transações
lista_conta_menos_10_transacao = []

for linha in tabela_menos_10_transacao['Conta Origem Transacao']:
    lista_conta_menos_10_transacao.append(linha)

print(lista_conta_menos_10_transacao)
# Out:
# [1426538, 1459889, 1524997, 1699507, 1716868, 1979681, 2036165, 2507159, 2745571, 2816647, 2987430, 3394696, 3489011, 3499072, 3573422, 3770984, 3847727, 4681642, 4779074, 4911058, 5186737, 5193866, 5365171, 5487087, 5664914, 5763071, 5812144, 5954411, 6256174, 6431645, 6547371, 6704562, 7004593, 7181109, 7439183, 7607098, 8048679, 8720104, 8868672, 8877004, 9211792, 9539657, 9996164]

# %% [markdown]
# Agora vou criar as duas tabelas, uma contendo só os clientes que vão receber o benefício e a outra com clientes sem benefício.

# %%
# Clientes com o benefício
clientes_com_beneficio = clientes[clientes['Número da Conta'].isin(lista_conta_mais_9_transacao)]
clientes_com_beneficio
# Out:
#    ID Cliente Data Nascimento  Idade Gênero  \
# 8        H009      1964-04-01   59.0      F
# 9        H010      1964-01-06   59.0      F
# 36       H037      1965-08-05   58.0      F
# 39       H040      1964-04-01   59.0      M
# 40       H041      1973-01-06   50.0      M
# 45       H046      1997-02-27   26.0      F
# 48       H049      1966-04-08   57.0      F
#
#                              Endereço        Telefone  Número da Conta  \
# 8         Rua Kiele Deme, 7271 centro  (98) 942216405          6600189
# 9       Rua Uriah Firmin, 8677 centro  (98) 939451468          1411453
# 36        Rua Mike Drury, 8013 centro  (61) 981720007          2265968
# 39    Rua Dante Cotilard, 8016 centro  (81) 993765169          6520787
# 40   Rua Anselm Caulcutt, 4802 centro  (83) 989882612          7972394
# 45  Rua Cathleen Wilbore, 4489 centro  (83) 901139740          6725534
# 48      Rua Shandie Kemp, 2479 centro  (51) 932154836          2236263
#
#         Nome Completo
# 8       Chan Marchesi
# 9     Fernanda Freire
# 36    Fernanda Taylor
# 39   Cícero Bernhardt
# 40    Raphael Freitas
# 45  Adrielle Assunção
# 48     Juliana Tostes

# %%
# Clientes sem o benefício
clientes_sem_beneficio = clientes[clientes['Número da Conta'].isin(lista_conta_menos_10_transacao)]
clientes_sem_beneficio
# Out:
#    ID Cliente Data Nascimento  Idade Gênero  \
# 0        H001      1966-04-08   57.0      M
# 1        H002      1985-05-14   38.0      M
# 2        H003      1965-08-12   58.0      F
# 3        H004      1998-02-15   25.0      M
# 4        H005      1968-08-08   55.0      F
# 5        H006      1965-08-05   58.0      F
# 6        H007      1964-05-09   59.0      F
# 7        H008      1984-07-07   39.0      M
# 10       H011      1999-11-04   24.0      F
# 11       H012      1998-01-18   25.0      M
# 12       H013      1994-08-06   29.0      M
# 13       H014      1978-05-09   45.0      M
# 14       H015      1979-02-27   44.0      M
# 15       H016      1975-04-28   48.0      M
# 16       H017      1995-06-26   28.0      F
# 17       H018      1966-05-08   57.0      M
# 18       H019      1966-05-14   57.0      M
# 19       H020      1965-08-15   58.0      F
# 20       H021      1982-02-15   41.0      M
# 21       H022      1968-08-08   55.0      F
# 22       H023      1965-08-05   58.0      M
# 23       H024      1989-05-09   34.0      F
# 24       H025      1964-07-07   59.0      F
# 25       H026      2000-04-01   23.0      F
# 26       H027      1964-01-06   59.0      M
# 27       H028      1969-11-04   54.0      M
# 28       H029      1998-01-18   25.0      M
# 29       H030      2003-08-06   20.0      M
# 30       H031      1978-05-09   45.0      M
# 31       H032      1966-04-08   57.0      F
# 32       H033      1985-05-14   38.0      F
# 33       H034      1965-08-12   58.0      M
# 34       H035      1994-02-15   29.0      F
# 35       H036      1968-08-08   55.0      F
# 37       H038      1964-05-09   59.0      F
# 38       H039      1967-07-07   56.0      M
# 41       H042      1969-11-04   54.0      M
# 42       H043      1998-01-18   25.0      F
# 43       H044      1994-08-06   29.0      F
# 44       H045      1978-05-09   45.0      F
# 46       H047      1989-04-28   34.0      F
# 47       H048      1959-06-26   64.0      M
# 49       H050      2005-05-14   18.0      F
#
#                                 Endereço        Telefone  Número da Conta  \
# 0        Rua Winthrop Hedau, 2769 centro  (71) 921679744          3499072
# 1           Rua Mead Spargo, 4055 centro  (62) 954043135          8048679
# 2         Rua Gabbie Pottie, 2289 centro  (27) 909825530          3573422
# 3           Rua Tasia Croot, 9875 centro  (96) 946617185          5763071
# 4       Rua Seth Brailsford, 8134 centro  (86) 929775335          5954411
# 5          Rua Peggy Parmer, 8302 centro  (82) 992446706          1699507
# 6         Rua Mildrid Drane, 2032 centro  (68) 948576145          2507159
# 7          Rua Muriel Beste, 2636 centro  (63) 933027844          2745571
# 10      Rua Mozes Wickliffe, 5015 centro  (83) 940192383          8720104
# 11     Rua Renard Gravenell, 8517 centro  (88) 901527421          5193866
# 12          Rua Sal Loosely, 1632 centro  (86) 993872650          4779074
# 13        Rua Gardy Skippon, 3723 centro  (41) 923997232          2036165
# 14      Rua Candide Manolov, 1168 centro  (62) 970051595          9211792
# 15   Rua Prissie Witheridge, 6697 centro  (95) 983847686          1716868
# 16     Rua Reine Mclanachan, 4338 centro  (62) 968443268          6704562
# 17           Rua Gae Thowes, 6194 centro  (69) 993925290          7181109
# 18   Rua Leonerd Segebrecht, 1331 centro  (69) 915168994          7004593
# 19        Rua Paxon Shillum, 5744 centro  (88) 940567772          4911058
# 20     Rua Callean Bernetti, 1243 centro  (86) 992324924          3489011
# 21       Rua Marketa Dibley, 3326 centro  (68) 943665850          5487087
# 22     Rua Lissie Paolicchi, 9309 centro  (98) 978457502          6431645
# 23          Rua Saxe Boothe, 6864 centro  (86) 931735206          3770984
# 24      Rua Charmine Elgram, 1007 centro  (79) 921230380          7439183
# 25     Rua Victoria Caltera, 2703 centro  (84) 927896505          2987430
# 26        Rua Sammy Dansken, 1866 centro  (65) 995304740          5365171
# 27         Rua Karin Wimmer, 8986 centro  (98) 947493638          3847727
# 28        Rua Tedmund Jakov, 4093 centro  (84) 968414800          1426538
# 29         Rua Annis Merida, 9800 centro  (91) 944184729          5812144
# 30        Rua Ursola Bowick, 5930 centro  (62) 955949458          2816647
# 31      Rua Davidson Correa, 5747 centro  (71) 915122505          4681642
# 32         Rua Moria Simoni, 7790 centro  (41) 991221681          9996164
# 33  Rua Aubrette Campanelli, 4449 centro  (27) 920668719          1524997
# 34       Rua Jonell Fereday, 6237 centro  (48) 906603954          9539657
# 35       Rua Lyndell Tilbey, 2481 centro  (84) 946412449          8868672
# 37   Rua Franklyn Woolcocks, 3969 centro  (92) 910641218          5186737
# 38     Rua Fred Summerfield, 9742 centro  (11) 926142846          6547371
# 41       Rua Zondra Gillise, 4881 centro  (83) 999460564          7607098
# 42      Rua Domingo Sprules, 7434 centro  (61) 959932281          1459889
# 43      Rua Garrett Gobeaux, 9966 centro  (61) 992242682          8877004
# 44         Rua Weber Vigors, 8024 centro  (92) 930205453          6256174
# 46        Rua Davis Mcgarva, 2420 centro  (51) 914310078          1979681
# 47          Rua Dasha Kupka, 5775 centro  (31) 984570190          3394696
# 49       Rua Farlie Beachem, 7902 centro  (84) 925534918          5664914
#
#              Nome Completo
# 0      Sthefeson Bernhardt
# 1          Antonio Vannier
# 2             Bianca Kranz
# 3           Silvio Almeida
# 4             Luiza Moraes
# 5            Ana Villanova
# 6           Natalia Amaral
# 7            Leonardo Lima
# 10            Raissa Souza
# 11            Arthur Assis
# 12          Eduardo Barros
# 13             João Correa
# 14            Caio Almeida
# 15          Tiago Ferreira
# 16           Julia Pimenta
# 17      Bernardo Wajnsztok
# 18        Victor Conceição
# 19             Thays Mello
# 20              Ruan Rocha
# 21           Mariana Alves
# 22  Alexandre Vasconcellos
# 23          Natalia Araujo
# 24            Manuela Melo
# 25             Bruna Netto
# 26               Caio Maia
# 27      Bernardo Viríssimo
# 28        Rodrigo Carvalho
# 29         Pedro Magalhães
# 30       Giuseppe Mendonça
# 31            Isabela Maia
# 32            Raíza Mendes
# 33          Wilson Santana
# 34           Larissa Zakhm
# 35            Luíza Albino
# 37        Bianca Assumpção
# 38            Diogo Veloso
# 41          Fabio Capitulo
# 42      Manuela Cavalcanti
# 43            Juliana Lima
# 44          Jéssica Barros
# 46          Thayna Accardo
# 47             Pedro Jesus
# 49              Tayla Melo

# %% [markdown]
# ### Criando os dois arquivos
#
# - Será criado um arquivo csv contendo todos os clientes que vão receber a oferta especial.
# - E outro arquivo csv com clientes que não receberão nenhum tipo de oferta.

# %%
# Arquivo com os clientes beneficiados
clientes_com_beneficio.to_csv('clientes_com_ofertas_especiais.csv')

# %%
# Arquivo com os clientes sem benefícios
clientes_sem_beneficio.to_csv('clientes_sem_ofertas_especiais.csv')

# %% [markdown]
# ### Considerações Finais
#
# #### Objetivos:
# - Esse projeto foi criado para saber quais clientes vão receber descontos e ofertas especiais.
# - Com esse arquivo contendo os clientes beneficiados, o setor responsável pode enviar uma mensagem para cada cliente parabenizando-os e mostrar para eles que quanto mais movimentos e operações se faz na conta mais chance tem de serem muito mais beneficiados.
# - E o outro arquivo contendo os clientes com menos transações, o setor pode pegar esses dados e também mandar uma mensagem incentivando eles a no próximo ano fazerem mais operações na suas contas para ganharem descontos e ofertas especiais.
#
# #### Conclusão:
# - Depois de pegar as bases de dados com o cadastro de clientes e com as transações bancárias, foi feito as transformações necessárias e a criação de dois arquivos para serem enviados aos setores responsáveis.
# - Esse ETL ajudará a organização a fidelizar o cliente, pois mostra para os clientes que eles são valorizados. E também, ao setor de Marketing a distribuir mais anúncios focado nas contas com menos movimentações.
